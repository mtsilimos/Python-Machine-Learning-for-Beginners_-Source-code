# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from google.colab import drive
import pandas as pd
import plotly.express as px

# Mount Google Drive
drive.mount('/content/drive')

# Load data
df = pd.read_csv('/content/drive/My Drive/emotions.csv')

# Features and labels
X = df['Comment']
y = df['Emotion']

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Vectorize text data
vec = TfidfVectorizer(max_df=0.95, min_df=3, stop_words='english')  # Adjusted max_df
X_train_vectorized = vec.fit_transform(X_train)
X_test_vectorized = vec.transform(X_test)

# Initialize and train the classifier
classifier = RandomForestClassifier(random_state=42)
classifier.fit(X_train_vectorized, y_train)

# Training and test accuracy
y_train_pred = classifier.predict(X_train_vectorized)
y_test_pred = classifier.predict(X_test_vectorized)

print("Train accuracy:", accuracy_score(y_train, y_train_pred))
print("Test accuracy:", accuracy_score(y_test, y_test_pred))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Train accuracy: 0.9983152827918171
# Test accuracy: 0.9472502805836139

# %%
classifier =RandomForestClassifier()
classifier.fit(X_train_vectorized, y_train)

y_pred = classifier.predict(X_test_vectorized)

print("Test accuracy:", accuracy_score(y_test, y_pred))

y_pred = classifier.predict(X_train_vectorized)

print("Train accuracy:", accuracy_score(y_train, y_pred))

from sklearn.model_selection import GridSearchCV

params = {
   'n_estimators': [100, 200, 300],
   'max_features': [10, 20, 30],
   'min_samples_split': [4, 6, 8],
   'min_samples_leaf': [4, 6, 8]
}

grid = GridSearchCV(classifier, params, cv = 3, verbose = 3)
model = grid.fit(X_train_vectorized, y_train)



print('Best hyperparameters are '+str(model.best_params_))


final_model = model.best_estimator_
y_pred = final_model.predict(X_test_vectorized)

print("Test accuracy:", accuracy_score(y_test, y_pred))


y_pred = final_model.predict(X_train_vectorized)

print("Train accuracy:", accuracy_score(y_train, y_pred))
# Out:
# Test accuracy: 0.9455667789001122
# Train accuracy: 0.9983152827918171
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# [CV 1/3] END max_features=10, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.908 total time=   0.9s
# [CV 2/3] END max_features=10, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.888 total time=   1.5s
# [CV 3/3] END max_features=10, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.894 total time=   0.5s
# [CV 1/3] END max_features=10, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.906 total time=   1.1s
# [CV 2/3] END max_features=10, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.903 total time=   1.1s
# [CV 3/3] END max_features=10, min_samples_leaf=4, min_samples_split=4, n_estimators=200;, score=0.918 total time=   1.1s
# [CV 1/3] END max_features=10, min_samples_leaf=4, min_samples_split=4, n_estimators=300;, score=0.903 total time=   1.0s
# [CV 2/3] END max_features=10, min_samples_leaf=4, min_samples_split=4, n_estimators=300;, score=0.900 total time=   1.0s
# [CV 3/3] END max_features=10, min_samples_leaf=4, min_samples_split=4, n_estimators=300;, score=0.913 total time=   1.0s
# [CV 1/3] END max_features=10, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.913 total time=   0.3s
# [CV 2/3] END max_features=10, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.887 total time=   0.3s
# [CV 3/3] END max_features=10, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.907 total time=   0.3s
# [CV 1/3] END max_features=10, min_samples_leaf=4, min_samples_split=6, n_estimators=200;, score=0.902 total time=   0.7s
# [CV 2/3] END max_features=10, min_samples_leaf=4, min_samples_split=6, n_estimators=200;, score=0.899 total time=   0.7s
# [CV 3/3] END max_features=10, min_samples_leaf=4, min_samples_split=6, n_estimators=200;, score=0.912 total time=   0.7s
# [CV 1/3] END max_features=10, min_samples_leaf=4, min_samples_split=6, n_estimators=300;, score=0.910 total time=   1.0s
# [CV 2/3] END max_features=10, min_samples_leaf=4, min_samples_split=6, n_estimators=300;, score=0.900 total time=   1.0s
# [CV 3/3] END max_features=10, min_samples_leaf=4, min_samples_split=6, n_estimators=300;, score=0.912 total time=   1.0s
# [CV 1/3] END max_features=10, min_samples_leaf=4, min_samples_split=8, n_estimators=100;, score=0.895 total time=   0.3s
# [CV 2/3] END max_features=10, min_samples_leaf=4, min_samples_split=8, n_estimators=100;, score=0.903 total time=   0.4s
# [CV 3/3] END max_features=10, min_samples_leaf=4, min_samples_split=8, n_estimators=100;, score=0.892 total time=   0.5s
# [CV 1/3] END max_features=10, min_samples_leaf=4, min_samples_split=8, n_estimators=200;, score=0.904 total time=   1.0s
# [CV 2/3] END max_features=10, min_samples_leaf=4, min_samples_split=8, n_estimators=200;, score=0.900 total time=   1.0s
# [CV 3/3] END max_features=10, min_samples_leaf=4, min_samples_split=8, n_estimators=200;, score=0.909 total time=   1.1s
# [CV 1/3] END max_features=10, min_samples_leaf=4, min_samples_split=8, n_estimators=300;, score=0.913 total time=   1.6s
# [CV 2/3] END max_features=10, min_samples_leaf=4, min_samples_split=8, n_estimators=300;, score=0.901 total time=   1.0s
# [CV 3/3] END max_features=10, min_samples_leaf=4, min_samples_split=8, n_estimators=300;, score=0.913 total time=   1.1s
# [CV 1/3] END max_features=10, min_samples_leaf=6, min_samples_split=4, n_estimators=100;, score=0.801 total time=   0.3s
# [CV 2/3] END max_features=10, min_samples_leaf=6, min_samples_split=4, n_estimators=100;, score=0.783 total time=   0.3s
# [CV 3/3] END max_features=10, min_samples_leaf=6, min_samples_split=4, n_estimators=100;, score=0.771 total time=   0.3s
# [CV 1/3] END max_features=10, min_samples_leaf=6, min_samples_split=4, n_estimators=200;, score=0.825 total time=   0.5s
# [CV 2/3] END max_features=10, min_samples_leaf=6, min_samples_split=4, n_estimators=200;, score=0.837 total time=   0.5s
# [CV 3/3] END max_features=10, min_samples_leaf=6, min_samples_split=4, n_estimators=200;, score=0.830 total time=   0.5s
# [CV 1/3] END max_features=10, min_samples_leaf=6, min_samples_split=4, n_estimators=300;, score=0.834 total time=   0.7s
# [CV 2/3] END max_features=10, min_samples_leaf=6, min_samples_split=4, n_estimators=300;, score=0.817 total time=   0.7s
# [CV 3/3] END max_features=10, min_samples_leaf=6, min_samples_split=4, n_estimators=300;, score=0.848 total time=   0.7s
# [CV 1/3] END max_features=10, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.805 total time=   0.2s
# [CV 2/3] END max_features=10, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0
END max_features=30, min_samples_leaf=6, min_samples_split=4, n_estimators=200;, score=0.884 total time=   1.8s
# [CV 3/3] END max_features=30, min_samples_leaf=6, min_samples_split=4, n_estimators=200;, score=0.894 total time=   1.7s
# [CV 1/3] END max_features=30, min_samples_leaf=6, min_samples_split=4, n_estimators=300;, score=0.893 total time=   1.8s
# [CV 2/3] END max_features=30, min_samples_leaf=6, min_samples_split=4, n_estimators=300;, score=0.883 total time=   1.7s
# [CV 3/3] END max_features=30, min_samples_leaf=6, min_samples_split=4, n_estimators=300;, score=0.889 total time=   1.9s
# [CV 1/3] END max_features=30, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.893 total time=   0.6s
# [CV 2/3] END max_features=30, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.887 total time=   0.6s
# [CV 3/3] END max_features=30, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.890 total time=   0.6s
# [CV 1/3] END max_features=30, min_samples_leaf=6, min_samples_split=6, n_estimators=200;, score=0.892 total time=   1.2s
# [CV 2/3] END max_features=30, min_samples_leaf=6, min_samples_split=6, n_estimators=200;, score=0.884 total time=   1.2s
# [CV 3/3] END max_features=30, min_samples_leaf=6, min_samples_split=6, n_estimators=200;, score=0.887 total time=   1.8s
# [CV 1/3] END max_features=30, min_samples_leaf=6, min_samples_split=6, n_estimators=300;, score=0.895 total time=   2.7s
# [CV 2/3] END max_features=30, min_samples_leaf=6, min_samples_split=6, n_estimators=300;, score=0.890 total time=   1.8s
# [CV 3/3] END max_features=30, min_samples_leaf=6, min_samples_split=6, n_estimators=300;, score=0.892 total time=   1.9s
# [CV 1/3] END max_features=30, min_samples_leaf=6, min_samples_split=8, n_estimators=100;, score=0.892 total time=   0.6s
# [CV 2/3] END max_features=30, min_samples_leaf=6, min_samples_split=8, n_estimators=100;, score=0.882 total time=   0.6s
# [CV 3/3] END max_features=30, min_samples_leaf=6, min_samples_split=8, n_estimators=100;, score=0.887 total time=   0.6s
# [CV 1/3] END max_features=30, min_samples_leaf=6, min_samples_split=8, n_estimators=200;, score=0.895 total time=   1.2s
# [CV 2/3] END max_features=30, min_samples_leaf=6, min_samples_split=8, n_estimators=200;, score=0.884 total time=   1.2s
# [CV 3/3] END max_features=30, min_samples_leaf=6, min_samples_split=8, n_estimators=200;, score=0.891 total time=   1.2s
# [CV 1/3] END max_features=30, min_samples_leaf=6, min_samples_split=8, n_estimators=300;, score=0.892 total time=   2.1s
# [CV 2/3] END max_features=30, min_samples_leaf=6, min_samples_split=8, n_estimators=300;, score=0.884 total time=   2.7s
# [CV 3/3] END max_features=30, min_samples_leaf=6, min_samples_split=8, n_estimators=300;, score=0.892 total time=   2.2s
# [CV 1/3] END max_features=30, min_samples_leaf=8, min_samples_split=4, n_estimators=100;, score=0.868 total time=   0.5s
# [CV 2/3] END max_features=30, min_samples_leaf=8, min_samples_split=4, n_estimators=100;, score=0.859 total time=   0.5s
# [CV 3/3] END max_features=30, min_samples_leaf=8, min_samples_split=4, n_estimators=100;, score=0.866 total time=   0.5s
# [CV 1/3] END max_features=30, min_samples_leaf=8, min_samples_split=4, n_estimators=200;, score=0.871 total time=   0.9s
# [CV 2/3] END max_features=30, min_samples_leaf=8, min_samples_split=4, n_estimators=200;, score=0.856 total time=   0.9s
# [CV 3/3] END max_features=30, min_samples_leaf=8, min_samples_split=4, n_estimators=200;, score=0.866 total time=   1.0s
# [CV 1/3] END max_features=30, min_samples_leaf=8, min_samples_split=4, n_estimators=300;, score=0.878 total time=   1.4s
# [CV 2/3] END max_features=30, min_samples_leaf=8, min_samples_split=4, n_estimators=300;, score=0.857 total time=   1.3s
# [CV 3/3] END max_features=30, min_samples_leaf=8, min_samples_split=4, n_estimators=300;, score=0.864 total time=   1.5s
# [CV 1/3] END max_features=30, min_samples_leaf=8, min_samples_split=6, n_estimators=100;, score=0.861 total time=   0.6s
# [CV 2/3] END max_features=30, min_samples_leaf=8, min_samples_split=6, n_estimators=100;, score=0.856 total time=   0.7s
# [CV 3/3] END max_features=30, min_samples_leaf=8, min_samples_split=6, n_estimators=100;, score=0.861 total time=   0.7s
# [CV 1/3] END max_features=30, min_samples_leaf=8, min_samples_split=6, n_estimators=200;, score=0.875 total time=   1.4s
# [CV 2/3] END max_features=30, min_samples_leaf=8, min_samples_split=6, n_estimators=200;, score=0.866 total time=   1.4s
# [CV 3/3] END max_features=30, min_samples_leaf=8, min_samples_split=6, n_estimators=200;, score=0.861 total time=   1.1s
# [CV 1/3] END max_features=30, min_samples_leaf=8, min_samples_split=6, n_estimators=300;, score=0.868 total time=   1.4s
# [CV 2/3] END max_features=30, min_samples_leaf=8, min_samples_split=6, n_estimators=300;, score=0.863 total time=   1.4s
# [CV 3/3] END max_features=30, min_samples_leaf=8, min_samples_split=6, n_estimators=300;, score=0.866 total time=   1.4s
# [CV 1/3] END max_features=30, min_samples_leaf=8, min_samples_split=8, n_estimators=100;, score=0.878 total time=   0.5s
# [CV 2/3] END max_features=30, min_samples_leaf=8, min_samples_split=8, n_estimators=100;, score=0.857 total time=   0.4s
# [CV 3/3] END max_features=30, min_samples_leaf=8, min_samples_split=8, n_estimators=100;, score=0.860 total time=   0.5s
# [CV 1/3] END max_features=30, min_samples_leaf=8, min_samples_split=8, n_estimators=200;, score=0.877 total time=   0.9s
# [CV 2/3] END max_features=30, min_samples_leaf=8, min_samples_split=8, n_estimators=200;, score=0.866 total time=   0.9s
# [CV 3/3] END max_features=30, min_samples_leaf=8, min_samples_split=8, n_estimators=200;, score=0.870 total time=   1.0s
# [CV 1/3] END max_features=30, min_samples_leaf=8, min_samples_split=8, n_estimators=300;, score=0.867 total time=   1.6s
# [CV 2/3] END max_features=30, min_samples_leaf=8, min_samples_split=8, n_estimators=300;, score=0.871 total time=   2.1s
# [CV 3/3] END max_features=30, min_samples_leaf=8, min_samples_split=8, n_estimators=300;, score=0.871 total time=   2.2s
# Best hyperparameters are {'max_features': 20, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# Test accuracy: 0.9264870931537598
# Train accuracy: 0.950661853188929

# %% [markdown]
# I suppose the problem below arose because the "y_test" of the final model was not assigned. Here the "y_test" is from the previous model and there is a mismatch between the "y_test" and the "y_pre" in the lines below.

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm

import plotly.express as px

fig = px.imshow(cm,
                labels=dict(x="Predicted values", y="Actual values", color="Productivity"),
                x=['anger', 'fear', 'joy'],
                y=['anger', 'fear', 'joy']
               )


fig.update_xaxes(side="bottom")

fig.update_traces(text=cm, texttemplate="%{text}")

fig.show()

print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-a6d1ace3af65> in <cell line: 0>()
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 cm = confusion_matrix(y_test, y_pred)
#       3 cm
#       4
#       5 import plotly.express as px
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     338     """
#     339     y_true, y_pred = attach_unique(y_true, y_pred)
# --> 340     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     341     if y_type not in ("binary", "multiclass"):
#     342         raise ValueError("%s is not supported" % y_type)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      96     """
#      97     xp, _ = get_namespace(y_true, y_pred)
# ---> 98     check_consistent_length(y_true, y_pred)
#      99     type_true = type_of_target(y_true, input_name="y_true")
#     100     type_pred = type_of_target(y_pred, input_name="y_pred")
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     473     uniques = np.unique(lengths)
#     474     if len(uniques) > 1:
# --> 475         raise ValueError(
#     476             "Found input variables with inconsistent numbers of samples: %r"
#     477             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [1782, 4155]
